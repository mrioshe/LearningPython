# %%
def comparar(l):
    n=0
    l1=[]
    for i in range(len(l)):
        if l[i] == 's' or l[i] == 'a' or l[i] == 'r' or l[i] == 'm' or l[i] == 'g' or l[i] == 'o':
            l1.append(l[i])
    for j in range(len(l1)):
        if l1[j] == 's':
            l3=l1[j:]
            break
    l_index=[]
    if len(l3) >= 8:
        for t in range(len(l3)):
            if l3[t]=='s':
                l_index.append(t)
                for k in range(t,len(l3)):
                    if l[k]=='a':
                        l_index.append(k)
                        for m in range(k,len(l3)):
                            if l[m]=='r':
                                l_index.append(m)
                                for h in range(m,len(l3)):
                                    if l[h]=='a':
                                        l_index.append(h)
                                        for f in range(h,len(l3)):
                                            if l[f]=='m':
                                                l_index.append(f)
                                                for c in range(f,len(l3)):
                                                    if l[c]=='a':
                                                        l_index.append(c)
                                                        for v in range(c,len(l3)):
                                                            if l[v]=='g':
                                                                l_index.append(v)
                                                                for u in range(v,len(l3)):
                                                                    if l[u]=='o':
                                                                        l_index.append(u)
                                                                        n +=1
                                                                        for g in range(len(l_index)):
                                                                            l3.pop(l_index[g]- g)
                                                                        l_index=[]
                                                                        break
                                                                break   
                                                        break   
                                                break    
                                        break   
                                break   
                        break  
                break 
            if len(l3) < 8:
                break
    else:
        n=0
    return(n,l3,l_index)

a=open('cameos.txt','r')
lista=[]
for renglones in a:
    for letras in renglones:
        lista.append(letras.lower())
    print(comparar(lista))
    lista=[]

a.close

# %% [markdown]
# comparar( ['m', 'i', 'e', 'n', 't', 'r', 'a', 's', ' ', 's', 'u', 'f', 'r', 'i', 'a', ' ', 'd', 'e', ' ', 's', 'a', 'r', 'a', 'm', 'p', 'i', 'o', 'n', ' ', 'a', 's', 'a', 'b', 'a', ' ', 'n', 'u', 'e', 'c', 'e', 's', ' ', 'e', 'n', ' ', 'e', 'l', ' ', 'm', 'a', 'g', 'o', 's', 't', 'o', '.', '\n'])

# %%
l1=comparar( ['s', 'a', 'r', 'a', 'm', 'a', 'g', 'o','w','s','s', 'a', 'r', 'a', 'm', 'a', 'g', 'o'])

# %%
l1

# %%
def mcd(a, b):
	resto = 0
	while(b > 0):
		resto = b
		b = a % b
		a = resto
	return a

# %%
mcd(4,2)

# %%
mcd(48,12)

# %%
n=0
while w <= cameos_max :
    l_index==[]
    for j in range(len(l3)):
        if l3[j]=='s':
            l_index.append(j)
            for k in range(j,len(l3)):
                if l[k]=='a':
                    l_index.append(k)
                    for m in range(k,len(l3)):
                        if l[m]=='r':
                            l_index.append(m)
                            for h in range(m,len(l3)):
                                if l[h]=='a':
                                    l_index.append(h)
                                    for f in range(h,len(l3)):
                                        if l[f]=='m':
                                            l_index.append(f)
                                            for c in range(f,len(l3)):
                                                if l[c]=='a':
                                                    l_index.append(c)
                                                    for v in range(c,len(l3)):
                                                        if l[v]=='g':
                                                            l_index.append(v)
                                                            for u in range(v,len(l3)):
                                                                if l[u]=='o':
                                                                    l_index.append(u)
                                                                    break
                                                            break
                                                    break
                                            break
                                    break
                            break
                    break
            break
    n +=1
    for g in range(len(l_index)):
        l3.pop(l_index(g))

# %%
    '''return(l2)
    def mcd(a, b):
    resto = 0
    while(b > 0):
        resto = b
        b = a % b
        a = resto
return a

def num_cameos(l3):
    cont_s=0
    cont_a=0
    cont_r=0
    cont_m=0
    cont_g=0
    cont_o=0
    for i in range(len(l3)):
        if l3[i]=='s':
            cont_s += 1
        elif l3[i]== 'a':
            cont_a +=1
        elif l3[i]== 'r':
            cont_r +=1
        elif l3[i]== 'm':
            cont_m +=1
        elif l3[i]== 'g':
            cont_g +=1
        else
            cont_o +=1
    if cont_s == 0 or  cont_a < 3 or  cont_r == 0 or  cont_m == 0 or  cont_g == 0 or cont_0 == 0:
        n=0:
    else:
        cameos_max=mcd(cont_a,min([cont_s,cont_r,cont_m,cont_g,cont_o])'''

# %%
([0, 6, 12, 14], ['s', 's', 'r', 'a', 's', 'a', 'r', 'a', 'm', 'o', 'a', 's', 'a', 'a', 's', 'm', 'a', 'g', 'o', 's', 'o'], 0)
([0], ['s', 'a', 'm', 'o', 's', 'g', 'o', 's', 'g', 'o', 's', 'o', 'o'], 0)
([0, 10, 11, 12, 17, 18, 20, 21], ['s', 'a', 'r', 'a', 'm', 'a', 'r', 'g', 'o', 'o', 'a', 's', 'a', 'a', 'g', 'o', 'r', 'a', 'm', 'r', 'o', 'a', 'g', 's', 'a', 'o'], 1)

# %%
l3=['a','b','c','d','e','f']
l_index=[1,3,4]
for g in range(len(l_index)):
    l3.pop(l_index[g]- g)

# %%
l3

# %%
def comparar(l):
    n=0
    l1=[]
    for i in range(len(l)):
        if l[i] == 's' or l[i] == 'a' or l[i] == 'r' or l[i] == 'm' or l[i] == 'g' or l[i] == 'o':
            l1.append(l[i])
    for j in range(len(l1)):
        if l1[j] == 's':
            l2=l1[j:]
            break
    for i in range(len(l3))
    
    return(n,l3,l_index)

# %%
def comparar2(l3):
    for j in range(len(l3)):
        if l3[j] == 's':
            l3=l3[j:]
            break
    n=0
    while len(l3) >= 8:
        control = False
        for t in range(len(l3)):
            if l3[t]=='s':
                for k in range(t,len(l3)):
                    if l3[k]=='a':
                        for m in range(k,len(l3)):
                            if l3[m]=='r':
                                for h in range(m,len(l3)):
                                    if l3[h]=='a':
                                        for f in range(h,len(l3)):
                                            if l3[f]=='m':
                                                for c in range(f,len(l3)):
                                                    if l3[c]=='a':
                                                        for v in range(c,len(l3)):
                                                            if l3[v]=='g':
                                                                for u in range(v,len(l3)):
                                                                    if l3[u]=='o':
                                                                        n+=1
                                                                        l3=l3[v:len(l3)]
                                                                        break
                                                                break   
                                                        break   
                                                break    
                                        break   
                                break   
                        break  
                break
        break
        for e in range(len(l3)):
            if l3[e] == 's':
                l3=l3[j:]
            break
    return(n)

# %%
comparar2(['s', 'a', 'r', 'a', 'm', 'a', 'r', 'g', 'o', 'o', 'a', 's', 'a', 'a', 'g', 'o', 'r', 'a', 'm', 'r', 'o', 'a', 'g', 's', 'a', 'o'])

# %%
l2=['s', 'a', 'r', 'a', 'm', 'a', 'r', 'g', 'o', 'o', 'a', 's', 'a', 'a', 'g', 'o', 'r', 'a', 'm', 'r', 'o', 'a', 'g', 's', 'a','o']

# %%
def buscar(l3):   
    for j in range(len(l3)):
        if l3[j] == 's':
            l3=l3[j:]
            break
    u=0
    control=False
    for t in range(len(l3)):
        if l3[t]=='s':
            for k in range(t,len(l3)):
                if l3[k]=='a':
                    for m in range(k,len(l3)):
                        if l3[m]=='r':
                            for h in range(m,len(l3)):
                                if l3[h]=='a':
                                    for f in range(h,len(l3)):
                                        if l3[f]=='m':
                                            for c in range(f,len(l3)):
                                                if l3[c]=='a':
                                                    for v in range(c,len(l3)):
                                                        if l3[v]=='g':
                                                            for u in range(v,len(l3)):
                                                                if l3[u]=='o':
                                                                    control = True 
                                                                    #n+=1
                                                                    #l3=l3[u+1:len(l3)]
                                                                    break
                                                            break   
                                                    break   
                                            break    
                                    break   
                            break   
                    break  
            break
    return(control,u+1)

def comparar(l):
    l2=[]
    for i in range(len(l)):
        if l[i] == 's' or l[i] == 'a' or l[i] == 'r' or l[i] == 'm' or l[i] == 'g' or l[i] == 'o':
            l2.append(l[i])
    a=buscar(l2)
    n=0
    while len(l2) >= 8:
        if a[0]==False:
            break
        else:
            n+=1
            b=a[1]
            a=buscar(l2[b:len(l2)])
    return n

a=open('cameos.txt','r')
lista=[]
for renglones in a:
    for letras in renglones:
        lista.append(letras.lower())
    print(comparar(lista))
    lista=[]

a.close

# %%
def contar(l3):
    cx=True
    u=0
    for t in range(len(l3)):
        if l3[t]=='s':
            for k in range(t,len(l3)):
                if l3[k]=='a':
                    for m in range(k,len(l3)):
                        if l3[m]=='r':
                            for h in range(m,len(l3)):
                                if l3[h]=='a':
                                    for f in range(h,len(l3)):
                                        if l3[f]=='m':
                                            for c in range(f,len(l3)):
                                                if l3[c]=='a':
                                                    for v in range(c,len(l3)):
                                                        if l3[v]=='g':
                                                            for u in range(v,len(l3)):
                                                                if l3[u]=='o':
                                                                    cx=True 
                                                                    break
                                                            break   
                                                    break   
                                            break    
                                    break   
                            break   
                    break  
            break
    return(cx,u)
    
a=open('cameos.txt','r')
cc=0
for renglones in a:
    while contar(renglones)[0]==True:
            cc+=1
            renglones=renglones[contar(renglones)[1]:]
        

a.close

# %%
l3

# %%
renglones[3:]

# %%
    c=0
    l3=renglones
    for t in range(len(l3)):
        if l3[t]=='s':
            for k in range(t,len(l3)):
                if l3[k]=='a':
                    for m in range(k,len(l3)):
                        if l3[m]=='r':
                            for h in range(m,len(l3)):
                                if l3[h]=='a':
                                    for f in range(h,len(l3)):
                                        if l3[f]=='m':
                                            for c in range(f,len(l3)):
                                                if l3[c]=='a':
                                                    for v in range(c,len(l3)):
                                                        if l3[v]=='g':
                                                            for u in range(v,len(l3)):
                                                                if l3[u]=='o':
                                                                    c += 1 
                                                                    l3=l3[u:]

                                                                    break
                                                            break   
                                                    break   
                                            break    
                                    break   
                            break   
                    break  
            break
